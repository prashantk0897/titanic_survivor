# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test=pd.read_csv("test.csv")
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df1=df.drop(['Name','Ticket','Cabin','Embarked'], axis='columns')
df1
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
# [891 rows x 8 columns]

# %%
dummy=pd.get_dummies(df1.Sex)
dummy
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
merged=pd.concat([df1,dummy],axis='columns')
merged
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# ...

# %%
df2=merged.drop(['Sex'],axis='columns')
df2
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  female  male
# 0              1         0       3  22.0      1      0   7.2500       0     1
# 1              2         1       1  38.0      1      0  71.2833       1     0
# 2              3         1       3  26.0      0      0   7.9250       1     0
# 3              4         1       1  35.0      1      0  53.1000       1     0
# 4              5         0       3  35.0      0      0   8.0500       0     1
# ..           ...       ...     ...   ...    ...    ...      ...     ...   ...
# 886          887         0       2  27.0      0      0  13.0000       0     1
# 887          888         1       1  19.0      0      0  30.0000       1     0
# 888          889         0       3   NaN      1      2  23.4500       1     0
# 889          890         1       1  26.0      0      0  30.0000       0     1
# 890          891         0       3  32.0      0      0   7.7500       0     1
#
# [891 rows x 9 columns]

# %%
plt.scatter(df2['Age'],df2['Survived'])
plt.scatter(df2['female'],df2['Survived'],color='r',marker='+')
plt.scatter(df2['male'],df2['Survived'],color='g',marker='*')

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# female           0
# male             0
# dtype: int64

# %%
df2.Age=df2.Age.fillna(df2.Age.mean())
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# female         0
# male           0
# dtype: int64

# %%
df3=df2.drop(['PassengerId','SibSp','Parch','male'],axis='columns')
df3
from sklearn.model_selection import train_test_split

# %%
x=df3.drop(['Survived'],axis='columns')
y=df3.Survived
y
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=20)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x,y)
# Out:
# GaussianNB()

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test1=test.drop(['SibSp','Parch','Name','Ticket','Cabin','Embarked'], axis='columns')
test1
# Out:
#      PassengerId  Pclass     Sex   Age      Fare
# 0            892       3    male  34.5    7.8292
# 1            893       3  female  47.0    7.0000
# 2            894       2    male  62.0    9.6875
# 3            895       3    male  27.0    8.6625
# 4            896       3  female  22.0   12.2875
# ..           ...     ...     ...   ...       ...
# 413         1305       3    male   NaN    8.0500
# 414         1306       1  female  39.0  108.9000
# 415         1307       3    male  38.5    7.2500
# 416         1308       3    male   NaN    8.0500
# 417         1309       3    male   NaN   22.3583
#
# [418 rows x 5 columns]

# %%
dummy1=pd.get_dummies(test1.Sex)
test2=pd.concat([test1,dummy1],axis='columns')
test2
# Out:
#      PassengerId  Pclass     Sex   Age      Fare  female  male
# 0            892       3    male  34.5    7.8292       0     1
# 1            893       3  female  47.0    7.0000       1     0
# 2            894       2    male  62.0    9.6875       0     1
# 3            895       3    male  27.0    8.6625       0     1
# 4            896       3  female  22.0   12.2875       1     0
# ..           ...     ...     ...   ...       ...     ...   ...
# 413         1305       3    male   NaN    8.0500       0     1
# 414         1306       1  female  39.0  108.9000       1     0
# 415         1307       3    male  38.5    7.2500       0     1
# 416         1308       3    male   NaN    8.0500       0     1
# 417         1309       3    male   NaN   22.3583       0     1
#
# [418 rows x 7 columns]

# %%
pid=test3.PassengerId
test3=test2.drop(['PassengerId','Sex','male'],axis='columns')
test3
# Out:
#      Pclass   Age      Fare  female
# 0         3  34.5    7.8292       0
# 1         3  47.0    7.0000       1
# 2         2  62.0    9.6875       0
# 3         3  27.0    8.6625       0
# 4         3  22.0   12.2875       1
# ..      ...   ...       ...     ...
# 413       3   NaN    8.0500       0
# 414       1  39.0  108.9000       1
# 415       3  38.5    7.2500       0
# 416       3   NaN    8.0500       0
# 417       3   NaN   22.3583       0
#
# [418 rows x 4 columns]

# %%
test3.isnull().sum()
# Out:
# Pclass     0
# Age       86
# Fare       1
# female     0
# dtype: int64

# %%
test3.Age=test3.Age.fillna(test3.Age.mean())
test3.Fare=test3.Fare.fillna(test3.Fare.mean())
test3
test3.isnull().sum()
# Out:
# Pclass    0
# Age       0
# Fare      0
# female    0
# dtype: int64

# %%
result=model.predict(test3)

# %%
ans=pd.DataFrame(result)
ans.columns=['Survived']
ans1=pd.concat([pid,ans],axis='columns')
ans1
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
ans1.to_csv('result.csv', index=False)

# %%
model.score(x_test,y_test)
# Out:
# 0.7686567164179104

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x, y)
knn.score(x_test, y_test)
# Out:
# 0.7126865671641791

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(x, y)
model.score(x_test, y_test)
# Out:
# 0.9738805970149254
